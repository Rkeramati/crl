# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
max_num = 500
value = np.zeros((max_num, 50))
for it in range(max_num):
    value[it, :] = np.load('cvars_%d.npy'%(it))

# %%
some = [0]
for c in some:
    plt.plot(value[:, c])
#plt.plot(np.ones(max_num) * -34.70)

# %%
plt.plot(np.load('returns.npy'))
